# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
from pgmpy.models import BayesianNetwork
from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.inference import VariableElimination

# %%
data = pd.read_csv(r"F:\SidOP\ProcessedCleveland.csv")
data
# Out:
#      63.0  1.0  1.0.1  145.0  233.0  1.0.2  2.0  150.0  0.0  2.3  3.0 0.0.1  \
# 0    67.0  1.0    4.0  160.0  286.0    0.0  2.0  108.0  1.0  1.5  2.0   3.0
# 1    67.0  1.0    4.0  120.0  229.0    0.0  2.0  129.0  1.0  2.6  2.0   2.0
# 2    37.0  1.0    3.0  130.0  250.0    0.0  0.0  187.0  0.0  3.5  3.0   0.0
# 3    41.0  0.0    2.0  130.0  204.0    0.0  2.0  172.0  0.0  1.4  1.0   0.0
# 4    56.0  1.0    2.0  120.0  236.0    0.0  0.0  178.0  0.0  0.8  1.0   0.0
# ..    ...  ...    ...    ...    ...    ...  ...    ...  ...  ...  ...   ...
# 297  45.0  1.0    1.0  110.0  264.0    0.0  0.0  132.0  0.0  1.2  2.0   0.0
# 298  68.0  1.0    4.0  144.0  193.0    1.0  0.0  141.0  0.0  3.4  2.0   2.0
# 299  57.0  1.0    4.0  130.0  131.0    0.0  0.0  115.0  1.0  1.2  2.0   1.0
# 300  57.0  0.0    2.0  130.0  236.0    0.0  2.0  174.0  0.0  0.0  2.0   1.0
# 301  38.0  1.0    3.0  138.0  175.0    0.0  0.0  173.0  0.0  0.0  1.0     ?
#
#      6.0  0
# 0    3.0  2
# 1    7.0  1
# 2    3.0  0
# 3    3.0  0
# 4    3.0  0
# ..   ... ..
# 297  7.0  1
# 298  7.0  2
# 299  7.0  3
# 300  3.0  1
# 301  3.0  0
#
# [302 rows x 14 columns]

# %%
data.isnull().sum()
# Out:
# 63.0     0
# 1.0      0
# 1.0.1    0
# 145.0    0
# 233.0    0
# 1.0.2    0
# 2.0      0
# 150.0    0
# 0.0      0
# 2.3      0
# 3.0      0
# 0.0.1    0
# 6.0      0
# 0        0
# dtype: int64

# %%
data.shape
# Out:
# (302, 14)

# %%
data.columns = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalac', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'HeartDisease']
data.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalac  exang  oldpeak  \
# 0  67.0  1.0  4.0     160.0  286.0  0.0      2.0   108.0    1.0      1.5
# 1  67.0  1.0  4.0     120.0  229.0  0.0      2.0   129.0    1.0      2.6
# 2  37.0  1.0  3.0     130.0  250.0  0.0      0.0   187.0    0.0      3.5
# 3  41.0  0.0  2.0     130.0  204.0  0.0      2.0   172.0    0.0      1.4
# 4  56.0  1.0  2.0     120.0  236.0  0.0      0.0   178.0    0.0      0.8
#
#    slope   ca thal  HeartDisease
# 0    2.0  3.0  3.0             2
# 1    2.0  2.0  7.0             1
# 2    3.0  0.0  3.0             0
# 3    1.0  0.0  3.0             0
# 4    1.0  0.0  3.0             0

# %%
data.isnull().sum()
# Out:
# age             0
# sex             0
# cp              0
# trestbps        0
# chol            0
# fbs             0
# restecg         0
# thalac          0
# exang           0
# oldpeak         0
# slope           0
# ca              0
# thal            0
# HeartDisease    0
# dtype: int64

# %%
# !pip install pgmpy
# Out:
# Collecting pgmpy
#   Downloading pgmpy-0.1.19-py3-none-any.whl (1.9 MB)
# Requirement already satisfied: statsmodels in c:\users\admin\anaconda3\lib\site-packages (from pgmpy) (0.13.2)
# Requirement already satisfied: scipy in c:\users\admin\anaconda3\lib\site-packages (from pgmpy) (1.7.3)
# Requirement already satisfied: scikit-learn in c:\users\admin\anaconda3\lib\site-packages (from pgmpy) (1.0.2)
# Requirement already satisfied: pyparsing in c:\users\admin\anaconda3\lib\site-packages (from pgmpy) (3.0.4)
# Collecting torch
#   Downloading torch-1.12.1-cp39-cp39-win_amd64.whl (161.8 MB)
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\lib\site-packages (from pgmpy) (1.4.2)
# Requirement already satisfied: numpy in c:\users\admin\anaconda3\lib\site-packages (from pgmpy) (1.21.5)
# Requirement already satisfied: tqdm in c:\users\admin\anaconda3\lib\site-packages (from pgmpy) (4.64.0)
# Requirement already satisfied: joblib in c:\users\admin\anaconda3\lib\site-packages (from pgmpy) (1.1.0)
# Requirement already satisfied: networkx in c:\users\admin\anaconda3\lib\site-packages (from pgmpy) (2.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas->pgmpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas->pgmpy) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->pgmpy) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn->pgmpy) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\admin\anaconda3\lib\site-packages (from statsmodels->pgmpy) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\admin\anaconda3\lib\site-packages (from statsmodels->pgmpy) (21.3)
# Requirement already satisfied: typing-extensions in c:\users\admin\anaconda3\lib\site-packages (from torch->pgmpy) (4.1.1)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from tqdm->pgmpy) (0.4.4)
# Installing collected packages: torch, pgmpy
# Successfully installed pgmpy-0.1.19 torch-1.12.1

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.410596    0.678808    3.165563  131.645695  246.738411    0.145695
# std      9.040163    0.467709    0.953612   17.612202   51.856829    0.353386
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     55.500000    1.000000    3.000000  130.000000  241.500000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg      thalac       exang     oldpeak       slope  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.986755  149.605960    0.327815    1.035430    1.596026
# std      0.994916   22.912959    0.470196    1.160723    0.611939
# min      0.000000   71.000000    0.000000    0.000000    1.000000
# 25%      0.000000  133.250000    0.000000    0.000000    1.000000
# 50%      0.500000  153.000000    0.000000    0.800000    2.000000
# 75%      2.000000  166.000000    1.000000    1.600000    2.000000
# max      2.000000  202.000000    1.000000    6.200000    3.000000
#
#        HeartDisease
# count    302.000000
# mean       0.940397
# std        1.229384
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        2.000000
# max        4.000000

# %%
data.count()
# Out:
# age             302
# sex             302
# cp              302
# trestbps        302
# chol            302
# fbs             302
# restecg         302
# thalac          302
# exang           302
# oldpeak         302
# slope           302
# ca              302
# thal            302
# HeartDisease    302
# dtype: int64
